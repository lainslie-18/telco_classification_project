# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from scipy import stats
import env
import acquire
import prepare
import os

# turn off pink boxes for demo
import warnings
warnings.filterwarnings("ignore")

# %%
train, validate, test = prepare.prep_telco_data(acquire.get_telco_data())

# %%
train.head()
# Out:
#       senior_citizen  tenure    multiple_lines  monthly_charges  \
# 1196               0      63               Yes            68.80
# 4239               1      23                No            75.40
# 846                0      42  No phone service            45.10
# 6014               0      60                No            20.55
# 6667               0       1               Yes            25.75
#
#       total_charges   contract_type internet_service_type  \
# 1196        4111.35        One year                   DSL
# 4239        1643.55  Month-to-month           Fiber optic
# 846         2049.05        One year                   DSL
# 6014        1205.05        Two year                  None
# 6667          25.75  Month-to-month                  None
#
#                    payment_type  is_male  has_partner  ...  \
# 1196  Bank transfer (automatic)        1            0  ...
# 4239  Bank transfer (automatic)        0            0  ...
# 846     Credit card (automatic)        1            1  ...
# 6014               Mailed check        1            1  ...
# 6667               Mailed check        0            0  ...
#
#       month_to_month_contract  one_year_contract  two_year_contract  \
# 1196                        0                  1                  0
# 4239                        1                  0                  0
# 846                         0                  1                  0
# 6014                        0                  0                  1
# 6667                        1                  0                  0
#
#       dsl_internet  fiber_optic_internet  no_internet_service  \
# 1196             1                     0                    0
# 4239             0                     1                    0
# 846              1                     0                    0
# 6014             0                     0                    1
# 6667             0                     0                    1
#
#       bank_transfer_payment_automatic  credit_card_payment_automatic  \
# 1196                                1                              0
# 4239                                1                              0
# 846                                 0                              1
# 6014                                0                              0
# 6667                                0                              0
#
#       electronic_check_payment  mailed_check_payment
# 1196                         0                     0
# 4239                         0                     0
# 846                          0                     0
# 6014                         0                     1
# 6667                         0                     1
#
# [5 rows x 32 columns]

# %%
print(train.shape)
print(validate.shape)
print(test.shape)
# Out:
# (3937, 32)
# (1688, 32)
# (1407, 32)
